# %% [markdown]
# <div class="jumbotron text-left"><b>
# This tutorial describes how to use the SMT toolbox with multifidelity data to build a surrogate model
# SMT which is a python toolbox for building a surrogate model.</b></div>
#
# Mostafa Meliani ISAE-SUPAERO student
#
# Nathalie BARTOLI ONERA/DTIS/M2CI - October 2025
# `version SMT 2.9.0 and above`

# %% [markdown]
# <p class="alert alert-success" style="padding:1em">
# To use SMT models, please follow this link : https://github.com/SMTorg/SMT/blob/master/README.md.
#     The doc is available here: http://smt.readthedocs.io/en/latest/
# </p>
#
#
# For the multifidelity extension, a description of the algorithm is available here https://arc.aiaa.org/doi/pdf/10.2514/6.2019-3236

# %%
# !pip install smt
# Out:
# Collecting smt
#   Downloading smt-2.9.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from smt) (25.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from smt) (1.6.1)
# Collecting pyDOE3 (from smt)
#   Downloading pydoe3-1.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from smt) (1.16.2)
# Collecting jenn (from smt)
#   Downloading jenn-1.0.8-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: jsonpointer>=2.4 in /usr/local/lib/python3.12/dist-packages (from jenn->smt) (3.0.0)
# Requirement already satisfied: jsonschema>=4.22 in /usr/local/lib/python3.12/dist-packages (from jenn->smt) (4.25.1)
# Requirement already satisfied: orjson>=3.9 in /usr/local/lib/python3.12/dist-packages (from jenn->smt) (3.11.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from jenn->smt) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from jenn->smt) (3.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->smt) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->smt) (3.6.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.22->jenn->smt) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.22->jenn->smt) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.22->jenn->smt) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.22->jenn->smt) (0.27.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->jenn->smt) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->jenn->smt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->jenn->smt) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->jenn->smt) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->jenn->smt) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->jenn->smt) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->jenn->smt) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->jenn->smt) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=4.22->jenn->smt) (4.15.0)
# Downloading smt-2.9.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (965 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.9/965.9 kB 12.4 MB/s eta 0:00:00
# Downloading jenn-1.0.8-py3-none-any.whl (35 kB)
# Downloading pydoe3-1.4.0-py2.py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: pyDOE3, jenn, smt
# Successfully installed jenn-1.0.8 pyDOE3-1.4.0 smt-2.9.5

# %% [markdown]
# # Multi-Fidelity Kriging
#
# We are interested in learning a high-fidelity function while using low-fidelity information sources to enhance the model, for that we use Le Gratiet recursive formulation of multi-fidelity Kriging.
#
# <p class="alert alert-warning" style="padding:1em">
# An important assumption by using this recursive formulation is the nested DOE.
# If we have thow fidelity levels (HF and LF)
# $$X_{HF} \subset X_{LF}$$
#  </p>
#
# ### Kennedy O'Hagan/Le Gratiet recursive formulation:
# To perform Le Gratiet's learning, we first learn the lowest fidelity, then we consecutively learn the relationship between every two consecutive fidelity levels (scaling factor $\rho_{k-1}$ and discrepancy function $\delta_k(\cdot)$).
#
# $$\mu_{k} = \rho_{k-1}\;\mu_{k-1} + \mu_{\delta_k}\\
# \sigma^2_{k} = \rho_{k-1}^2\;\sigma^2_{k-1}+\sigma^2_{\delta_k}$$
#
# ![Multi-Fidelity 1-D toy problem](https://github.com/dbetteb/early-ML/blob/master/09_SMT_NOTEBOOK/co-krigeage.png?raw=1)
#
# This generally results in a better surrogate model compared to training the high-fidelity alone.
#
# ### SMT
# SMT is a joint library between NASA, UoM, ONERA and ISAE-SUPAERO. It offers many surrogate modeling tools with a focus on derivatives. Le Gratiet's formulation was implemented as part of SMT.
#
# After dowmloading and installing SMT library from: https://github.com/SMTorg/smt
#
# We import the needed packages

# %%
from smt.applications import MFK
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1- Build a multifidelity model using two fidelity levels

# %%
#defining low and high fidelity functions
def LF_function(x):
    return 0.5*((x*6-2)**2)*np.sin((x*6-2)*2)+(x-0.5)*10. - 5

def HF_function(x):
    return ((x*6-2)**2)*np.sin((x*6-2)*2)

# %%
# Ploting High and low fidelity functions

x = np.linspace(0, 1, 101, endpoint = True).reshape(-1,1)
plt.figure()

plt.plot(x, HF_function(x), label ='High Fidelity')
plt.plot(x, LF_function(x), linestyle = '-.' , label ='Low Fidelity')

plt.legend(loc=0)
plt.ylim(-10,17)
plt.xlim(-0.1,1.1)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# #### Sampling
# The idea when building a mutli-fidelity design of experiment is to cover as much space as possible with low-fidelity data and use enough high fidelity samples to learn the relationship between fidelity-levels.

# %%
#Linear sampling
ndim=1

Xt_c = np.linspace(0, 1, 11, endpoint=True).reshape(-1, ndim)
#To have nested DOE
Xt_e = np.array([0.0,0.4, 0.7, 1.0]).reshape(-1, ndim)


# Evaluate the HF and LF functions
yt_e = HF_function(Xt_e)
yt_c = LF_function(Xt_c)

plt.plot(x, HF_function(x), label ='High Fidelity')
plt.plot(x, LF_function(x) , c ='k', label ='Low Fidelity')
plt.scatter(Xt_e, yt_e, marker = 'o' , color ='k', label ='HF doe')
plt.scatter(Xt_c, yt_c, marker = '*' , color ='g', label ='LF doe')

# %% [markdown]
# Building a SMT object has many options, you can check all the options in the doc website: http://smt.readthedocs.io

# %%
# build the MFK object
sm = MFK(theta0=Xt_e.shape[1] * [1.0])

# low-fidelity dataset names being integers from 0 to level -1
sm.set_training_values(Xt_c, yt_c, name = 0)
# high-fidelity dataset without name
sm.set_training_values(Xt_e, yt_e)

# train the model
sm.train()

# test training
x = np.linspace(0, 1, 101, endpoint = True).reshape(-1,1)

# query the outputs
y = sm.predict_values(x)
# Out:
# ___________________________________________________________________________
#
#                                     MFK
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 4
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.3062913
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0010850
#
#    Prediction time/pt. (sec) :  0.0000107

# %%
# plot the outputs
plt.plot(x, HF_function(x), label ='reference')
plt.plot(x, y, linestyle = '-.' , label ='mean_gp')
plt.scatter(Xt_e, yt_e, marker = 'o' , color ='k', label ='HF doe')
plt.scatter(Xt_c, yt_c, marker = '*' , color ='g', label ='LF doe')

plt.legend(loc=0)
plt.ylim(-10,17)
plt.xlim(-0.1,1.1)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
# Accessing the variance and derivative of the model
MSE = sm.predict_variances(x)
der = sm.predict_derivatives(x, kx=0)
# Out:
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0007663
#
#    Prediction time/pt. (sec) :  0.0000076

# %%
# plot the variance
plt.fill_between(np.ravel(x), np.ravel(y-2*np.sqrt(MSE)), np.ravel(y+2*np.sqrt(MSE)),color='grey' ,label ='Confidence Interval')
plt.plot(x, y, linestyle = '-.' , label ='mean_gp')
plt.scatter(Xt_e, yt_e, marker = 'o' , color ='k', label ='HF doe')
plt.scatter(Xt_c, yt_c, marker = '*' , color ='g', label ='LF doe')

plt.legend(loc=0)
plt.ylim(-10,17)
plt.xlim(-0.1,1.1)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %%
#comparing with only mono-fidelity GP
from smt.surrogate_models import KRG

gp = KRG(theta0=[1e-2])
gp.set_training_values(Xt_e, yt_e)
gp.train()

# query the outputs
gp_y = gp.predict_values(x)
gp_var = sm.predict_variances(x)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 4
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.1543500
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 101
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0004113
#
#    Prediction time/pt. (sec) :  0.0000041

# %%
# plot the variance
plt.plot(x, HF_function(x), 'k-', label ='High Fidelity')

plt.plot(x, y, linestyle = '-.' , label ='mean MFK 2 fidelities')
plt.fill_between(np.ravel(x), np.ravel(y-3*np.sqrt(MSE)), np.ravel(y+3*np.sqrt(MSE)),color='blue' , alpha =0.2, label ='99% Confidence Interval')

plt.plot(x, gp_y, linestyle = '-.' , label ='mean KRG 1 fidelity')
plt.fill_between(np.ravel(x), np.ravel(gp_y-3*np.sqrt(gp_var)), np.ravel(gp_y+3*np.sqrt(gp_var)),color='orange', alpha =0.2,label =' 99% Confidence Interval')

plt.scatter(Xt_e, yt_e, marker = 'o' , color ='k', label ='HF doe')
#plt.scatter(Xt_c, yt_c, marker = '*' , color ='g', label ='LF doe')

plt.legend(loc=0)
plt.ylim(-10,17)
plt.xlim(-0.1,1.1)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# This figures shows the interest of using Multifidelity data with MFK compared to mono fidelity GP to approximate the true function.
